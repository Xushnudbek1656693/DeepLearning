# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input  
import matplotlib.pyplot as plt

# %%
# Ma'lumot yaratamiz
X1 = np.random.rand(100, 1)  # 100ta input ma'lumot
y1 = X1 * 2 + 1  # y = 2x + 1
X1.shape
# Out:
# (100, 1)

# %%
# Model qurish
model1 = Sequential([
    Input(shape=(X1.shape[1],)),  # Bu rasmiy tavsiya qilingan usul
    Dense(units=1, activation=None)
])

# %%
# Kompilyatsiya
model1.compile(optimizer='adam', loss='mse')

# %%
# O‘qitish
history_model1 = model1.fit(X1, y1, epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.8703
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8647
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.9193
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8964
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8428
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8235
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8268
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8078
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7835
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.7688

# %%
# Model tuzilmasini ko‘rish
model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8 (36.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6 (28.00 B)

# %%
# Xatolik grafigi
plt.figure(figsize=(6, 4))
plt.plot(history_model1.history['loss'])
plt.title('model1: Xatolik (Loss)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Ma'lumot
X2 = np.random.rand(100, 3)  # 3ta input
y2 = np.random.randint(0, 2, (100, 1))  # 0 yoki 1 chiqadi

# %%
# Model qurish
model2 = Sequential([
    Input(shape=(X2.shape[1],)),  # 3ta input
    Dense(units=1, activation='sigmoid')  # 1ta chiqish, sigmoid
])

# %%
# Kompilyatsiya
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# O‘qitish
history_model2 = model2.fit(X2, y2, epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.4335 - loss: 0.7093
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4449 - loss: 0.7103
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4824 - loss: 0.7032
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4658 - loss: 0.7028
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4500 - loss: 0.7093
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4220 - loss: 0.7154
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4699 - loss: 0.7007
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4168 - loss: 0.7112
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4260 - loss: 0.7130
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.4270 - loss: 0.7189

# %%
# Model tuzilmasini ko‘rish
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14 (60.00 B)
#  Trainable params: 4 (16.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 10 (44.00 B)

# %%
# Xatolik va aniqlik grafigi
plt.figure(figsize=(12, 4))

# Xatolik (loss) grafigi
plt.subplot(1, 2, 1)
plt.plot(history_model2.history['loss'])
plt.title('model2: Xatolik (Loss)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Aniqlik (accuracy) grafigi
plt.subplot(1, 2, 2)
plt.plot(history_model2.history['accuracy'])
plt.title('model2: Aniqlik (Accuracy)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %%
# Ma'lumot
X3 = np.random.rand(100, 5)  # 5ta input
y3 = np.random.randint(0, 2, (100, 2))  # 2ta chiqish (0 yoki 1)

# %%
# Model qurish
model3 = Sequential([
    Input(shape=(X3.shape[1],)),  # 5ta input
    Dense(units=4, activation='relu'),  # 4ta neyron
    Dense(units=2, activation='sigmoid')  # 2ta chiqish, sigmoid (multi-label uchun)
])

# %%
# Kompilyatsiya (multi-label uchun binary_crossentropy kerak)
model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# O‘qitish
history_model3 = model3.fit(X3, y3, epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.7523 - loss: 0.8393
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7325 - loss: 0.8664
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7470 - loss: 0.8468
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7377 - loss: 0.8356
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7408 - loss: 0.8414
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7345 - loss: 0.8220
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7231 - loss: 0.8201
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7533 - loss: 0.7888
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7554 - loss: 0.8040
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7387 - loss: 0.7977

# %%
# Model tuzilmasini ko‘rish
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 4)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104 (420.00 B)
#  Trainable params: 34 (136.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 70 (284.00 B)

# %%
# Xatolik va aniqlik grafigi
plt.figure(figsize=(12, 4))

# Xatolik (loss) grafigi
plt.subplot(1, 2, 1)
plt.plot(history_model3.history['loss'])
plt.title('model3: Xatolik (Loss)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Aniqlik (accuracy) grafigi
plt.subplot(1, 2, 2)
plt.plot(history_model3.history['accuracy'])
plt.title('model3: Aniqlik (Accuracy)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %%
# Ma'lumot
X4 = np.random.rand(100, 5)  # 5ta input
y4 = np.random.randint(0, 2, (100, 3))  # 3ta chiqish (multi-label)

# %%
# Model qurish
model4 = Sequential([
    Input(shape=(X4.shape[1],)),  # 5ta input
    Dense(units=8, activation='relu'),  # 1-qatlam (5ta input → 8ta neyron)
    Dense(units=8, activation='relu'),  # 2-qatlam
    Dense(units=5, activation='relu'),  # 3-qatlam
    Dense(units=3, activation='sigmoid')  # Chiqish: 3ta natija (0 va 1 orasida)
])

# %%
# Kompilyatsiya (multi-label uchun binary_crossentropy kerak)
model4.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# O‘qitish
history_model4 = model4.fit(X4, y4, epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.1730 - loss: 0.6930
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.1855 - loss: 0.6924
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.1751 - loss: 0.6928
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1946 - loss: 0.6922
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2243 - loss: 0.6917
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1819 - loss: 0.6926
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.1910 - loss: 0.6918
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2458 - loss: 0.6918
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2438 - loss: 0.6912
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2875 - loss: 0.6909

# %%
# Model tuzilmasini ko‘rish
model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 8)              │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 5)              │            45 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │            18 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 551 (2.16 KB)
#  Trainable params: 183 (732.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 368 (1.44 KB)

# %%
# Xatolik va aniqlik grafigi
plt.figure(figsize=(12, 4))

# Xatolik (loss) grafigi
plt.subplot(1, 2, 1)
plt.plot(history_model4.history['loss'])
plt.title('model4: Xatolik (Loss)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

# Aniqlik (accuracy) grafigi
plt.subplot(1, 2, 2)
plt.plot(history_model4.history['accuracy'])
plt.title('model4: Aniqlik (Accuracy)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()
